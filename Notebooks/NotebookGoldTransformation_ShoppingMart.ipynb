# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
from pyspark.sql.functions import *

Orders_df = spark.read.parquet("Files/ShoppingMart_Silver_Orders/ShoppingMart_customers_orderdata")
reviews_df = spark.read.parquet("Files/ShoppingMart_Silver_Reviews/ShoppingMart_review")
social_df = spark.read.parquet("Files/ShoppingMart_Silver_Social_Media/ShoppingMart_social_media")
weblogs_df = spark.read.parquet("Files/ShoppingMart_Silver_Web_Logs/ShoppingMart_web_logs")
# Out:
# StatementMeta(, a85b499a-54de-4607-aeb5-6f1356607480, 3, Finished, Available, Finished, False)

# %%
display(weblogs_df)
# Out:
# StatementMeta(, a85b499a-54de-4607-aeb5-6f1356607480, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 71219c55-c58b-4bce-9723-99ffd0f18060)

# %%
# Aggregates web log data to measure engagement per user on each page and action
weblogs_df = weblogs_df.groupBy("user_id", "page", "action").count()
weblogs_df.write.mode("overwrite").parquet("Files/ShoppingMart_Gold_Web_Logs/ShoppingMart_web_logs")
# Out:
# StatementMeta(, a85b499a-54de-4607-aeb5-6f1356607480, 14, Finished, Available, Finished, False)

# %%
display(social_df)
# Out:
# StatementMeta(, a85b499a-54de-4607-aeb5-6f1356607480, 7, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 960ecaa8-f432-4b9d-9918-838eb9e77bdd)

# %%
# Aggregates unstructured social media to track sentiment trends across different platforms 
social_df = social_df.groupBy("platform","sentiment").count()
social_df.write.mode("overwrite").parquet("Files/ShoppingMart_Gold_Social_Media/ShoppingMart_social_media")
# display(social_df)
# Out:
# StatementMeta(, a85b499a-54de-4607-aeb5-6f1356607480, 15, Finished, Available, Finished, False)

# %%
display(reviews_df)
# Out:
# StatementMeta(, a85b499a-54de-4607-aeb5-6f1356607480, 9, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, cf0b6994-6bbb-4154-9353-4882f09b3ad0)

# %%
# Aggregates product reviews to calculte the average rating per perdroct

reviews_df = spark.read.parquet("Files/ShoppingMart_Silver_Reviews/ShoppingMart_review")
reviews_df = reviews_df.groupBy("product_id").agg(avg("rating").alias("AvgRating"))
reviews_df.write.mode("overwrite").parquet("Files/ShoppingMart_Gold_Reviews/ShoppingMart_reviews")
# display(reviews_df)
# Out:
# StatementMeta(, a85b499a-54de-4607-aeb5-6f1356607480, 16, Finished, Available, Finished, False)

# %%
Orders_df.write.mode("overwrite").parquet("Files/ShoppingMart_Gold_Orders/ShoppingMart_customers_orderdata")
# Out:
# StatementMeta(, a85b499a-54de-4607-aeb5-6f1356607480, 17, Finished, Available, Finished, False)
